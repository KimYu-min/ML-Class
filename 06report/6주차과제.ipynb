# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import mglearn
from sklearn.model_selection import train_test_split
from matplotlib import font_manager, rc
font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %% [markdown]
# ### 비지도 학습
# ### 주성분 분석

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler

cancer = load_breast_cancer()
scaler = StandardScaler()
scaler.fit(cancer.data)

# 데이터 전처리
X_scaled = scaler.transform(cancer.data)

# %%
from sklearn.decomposition import PCA

# 데이터의 처음 두 개 주성분만 유지
pca = PCA(n_components=2)

# cancer 데이터로 PCA 모델을 구축
pca.fit(X_scaled)

# 처음 두 개의 주성분을 사용하여 데이터 변환
X_pca = pca.transform(X_scaled)

print("원본 데이터 형태 : {}".format(str(X_scaled.shape)))
print("축소된 데이터 형태 : {}".format(str(X_pca.shape)))
# Out:
# 원본 데이터 형태 : (569, 30)
# 축소된 데이터 형태 : (569, 2)

# %% [markdown]
# ### K-Means 클러스터링

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans

# 2차원 데이터 생성
X, y = make_blobs(random_state=1)

# 클러스터 3개 군집 모델 생성
kmeans = KMeans(n_clusters=3)
kmeans.fit(X)
print(kmeans.labels_)
# Out:
# [1 0 0 0 2 2 2 0 1 1 0 0 2 1 2 2 2 1 0 0 2 0 2 1 0 2 2 1 1 2 1 1 2 1 0 2 0
#  0 0 2 2 0 1 0 0 2 1 1 1 1 0 2 2 2 1 2 0 0 1 1 0 2 2 0 0 2 1 2 1 0 0 0 2 1
#  1 0 2 2 1 0 1 0 0 2 1 1 1 1 0 1 2 1 1 0 0 2 2 1 2 1]

# %%
# 클러스터 5개 군집 모델 생성
kmeans = KMeans(n_clusters=5)
kmeans.fit(X)
print(kmeans.labels_)
# Out:
# [1 0 0 0 2 2 2 0 3 1 0 0 4 3 4 2 2 1 0 0 2 0 2 1 0 4 2 1 1 4 3 1 4 1 0 2 0
#  0 0 2 2 0 1 0 0 2 3 1 3 1 0 4 2 2 3 2 0 0 3 1 0 2 2 0 0 2 3 2 1 0 0 0 2 3
#  3 0 2 2 1 0 3 0 0 2 1 1 3 1 0 3 2 1 3 0 0 2 4 3 2 1]
